# %% [markdown]
# # CASSIA Analysis Tutorial
#
# This Python Notebook demonstrates a complete workflow using CASSIA for cell type annotation of single-cell RNA sequencing data. We'll analyze an intestinal cell dataset containing six distinct populations:
#
# 1.monocyte
#
# 2.plasma cells
#
# 3.cd8-positive, alpha-beta t cell
#
# 4.transit amplifying cell of large intestine
#
# 5.intestinal enteroendocrine cell
#
# 6.intestinal crypt stem cell

# %% [markdown]
# ## Setup and Environment Preparation
#
# First, let's install and import the required packages:

# %%
# !pip install CASSIA
# Out:
# csh: No such file or directory
# csh: Trying to start from "/cs/student/msc/aibh/2024/shekchu"
# Requirement already satisfied: CASSIA in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: numpy in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from CASSIA) (2.2.6)
# Requirement already satisfied: pandas in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from CASSIA) (2.3.1)
# Requirement already satisfied: openai>=1.0.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from CASSIA) (1.97.1)
# Requirement already satisfied: anthropic>=0.3.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from CASSIA) (0.59.0)
# Requirement already satisfied: requests>=2.25.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from CASSIA) (2.32.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (2.11.7)
# Requirement already satisfied: sniffio in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anthropic>=0.3.0->CASSIA) (4.14.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic>=0.3.0->CASSIA) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic>=0.3.0->CASSIA) (3.10)
# Requirement already satisfied: certifi in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic>=0.3.0->CASSIA) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic>=0.3.0->CASSIA) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic>=0.3.0->CASSIA) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic>=0.3.0->CASSIA) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic>=0.3.0->CASSIA) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic>=0.3.0->CASSIA) (0.4.1)
# Requirement already satisfied: tqdm>4 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from openai>=1.0.0->CASSIA) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from requests>=2.25.0->CASSIA) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from requests>=2.25.0->CASSIA) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from pandas->CASSIA) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from pandas->CASSIA) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from pandas->CASSIA) (2025.2)
# Requirement already satisfied: six>=1.5 in /cs/student/projects2/aisd/2024/shekchu/miniconda/envs/cassia/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->CASSIA) (1.17.0)

# %%
import CASSIA

# %%
# Set API keys
CASSIA.set_api_key("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", provider="openai")
# CASSIA.set_api_key("your-anthropic-key", provider="anthropic")
# CASSIA.set_api_key("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", provider="openrouter")

# %%
processed_markers = CASSIA.loadmarker(marker_type="processed")
unprocessed_markers = CASSIA.loadmarker(marker_type="unprocessed")
subcluster_results = CASSIA.loadmarker(marker_type="subcluster_results")

# List available marker sets
available_markers = CASSIA.list_available_markers()
print(available_markers)
# Out:
# ['processed', 'subcluster_results', 'unprocessed', 'cassia_format']

# %% [markdown]
# ## Fast Mode

# %%
# Run the CASSIA pipeline in fast mode
CASSIA.runCASSIA_pipeline(
    output_file_name = "FastAnalysisResults",
    tissue = "breast cancer",  
    species = "human",
    marker_path = unprocessed_markers,
    max_workers = 3,  # Matches the number of clusters in dataset
    annotation_model = "gpt-4o-2024-08-06", #openai/gpt-4o-2024-11-20
    annotation_provider = "openai",
    score_model = "gpt-4o-2024-08-06",
    score_provider = "openai",
    score_threshold = 75,
    annotationboost_model="gpt-4o-2024-08-06",
    annotationboost_provider="openai"
)
# Out:
# Created folder: CASSIA_breast_cancer_human_20250729_154121
#
# === Starting cell type analysis ===
# Processing input dataframe to get top markers
#
# Analyzing cluster_0...
#
# Analyzing cluster_1...
#
# Analyzing cluster_10...
# Analysis for cluster_10 completed.
#
#
# Analyzing cluster_11...
# Analysis for cluster_1 completed.
#
#
# Analyzing cluster_12...
# Analysis for cluster_0 completed.
#
#
# Analyzing cluster_13...
# Analysis for cluster_11 completed.
#
#
# Analyzing cluster_14...
# Analysis for cluster_12 completed.
#
#
# Analyzing cluster_15...
# Analysis for cluster_13 completed.
#
#
# Analyzing cluster_16...
# Analysis for cluster_14 completed.
#
#
# Analyzing cluster_17...
# Analysis for cluster_15 completed.
#
#
# Analyzing cluster_18...
# Analysis for cluster_16 completed.
#
#
# Analyzing cluster_19...
# Analysis for cluster_19 completed.
#
#
# Analyzing cluster_2...
# Analysis for cluster_17 completed.
#
#
# Analyzing cluster_20...
# Analysis for cluster_18 completed.
#
#
# Analyzing cluster_21...
# Analysis for cluster_20 completed.
#
#
# Analyzing cluster_22...
# Analysis for cluster_21 completed.
#
#
# Analyzing cluster_23...
# Analysis for cluster_22 completed.
#
#
# Analyzing cluster_24...
# Analysis for cluster_2 completed.
#
#
# Analyzing cluster_25...
# Analysis for cluster_23 completed.
#
#
# Analyzing cluster_26...
# Analysis for cluster_25 completed.
#
#
# Analyzing cluster_27...
# Analysis for cluster_24 completed.
#
#
# Analyzing cluster_28...
# Analysis for cluster_26 completed.
#
#
# Analyzing cluster_29...
# Analysis for cluster_27 completed.
#
#
# Analyzing cluster_3...
# Analysis for cluster_28 completed.
#
#
# Analyzing cluster_30...
# Analysis for cluster_29 completed.
#
#
# Analyzing cluster_31...
# Analysis for cluster_3 completed.
#
#
# Analyzing cluster_32...
# Analysis for cluster_30 completed.
#
#
# Analyzing cluster_33...
# Analysis for cluster_31 completed.
#
#
# Analyzing cluster_34...
# Analysis for cluster_32 completed.
#
#
# Analyzing cluster_35...
# Analysis for cluster_33 completed.
#
#
# Analyzing cluster_36...
# Analysis for cluster_34 completed.
#
#
# Analyzing cluster_37...
# Analysis for cluster_35 completed.
#
#
# Analyzing cluster_38...
# Analysis for cluster_36 completed.
#
#
# Analyzing cluster_39...
# Analysis for cluster_37 completed.
#
#
# Analyzing cluster_4...
# Analysis for cluster_39 completed.
#
#
# Analyzing cluster_40...
# Analysis for cluster_4 completed.
#
#
# Analyzing cluster_41...
# Analysis for cluster_38 completed.
#
#
# Analyzing cluster_42...
# Analysis for cluster_40 completed.
#
#
# Analyzing cluster_43...
# Analysis for cluster_42 completed.
#
#
# Analyzing cluster_44...
# Analysis for cluster_41 completed.
#
#
# Analyzing cluster_45...
# Analysis for cluster_43 completed.
#
#
# Analyzing cluster_46...
# Analysis for cluster_45 completed.
#
#
# Analyzing cluster_47...
# Analysis for cluster_44 completed.
#
#
# Analyzing cluster_48...
# Analysis for cluster_46 completed.
#
#
# Analyzing cluster_49...
# Analysis for cluster_47 completed.
#
#
# Analyzing cluster_5...
# Analysis for cluster_49 completed.
#
#
# Analyzing cluster_50...
# Analysis for cluster_48 completed.
#
#
# Analyzing cluster_51...
# Analysis for cluster_5 completed.
#
#
# Analyzing cluster_6...
# Analysis for cluster_51 completed.
#
#
# Analyzing cluster_7...
# Analysis for cluster_50 completed.
#
#
# Analyzing cluster_8...
# Analysis for cluster_6 completed.
#
#
# Analyzing cluster_9...
# Analysis for cluster_7 completed.
#
# Analysis for cluster_8 completed.
#
# Analysis for cluster_9 completed.
#
# All analyses completed. Results saved to 'FastAnalysisResults'.
# Two CSV files have been created:
# 1. FastAnalysisResults_full.csv (full data)
# 2. FastAnalysisResults_summary.csv (summary data)
# ✓ Cell type analysis completed
#
# === Starting scoring process ===
# Starting scoring process with 3 workers using openai (gpt-4o-2024-08-06)...
# Processed row 2: Score = 90
# Processed row 3: Score = 90
# Processed row 1: Score = 85
# Processed row 4: Score = 90
# Processed row 5: Score = 85
# Processed row 6: Score = 85
# Processed row 7: Score = 85
# Processed row 9: Score = 85
# Processed row 11: Score = 85
# Processed row 10: Score = 90
# Processed row 8: Score = 90
# Processed row 12: Score = 90
# Processed row 13: Score = 90
# Processed row 15: Score = 90
# Processed row 14: Score = 90
# Processed row 16: Score = 85
# Processed row 19: Score = 90
# Processed row 17: Score = 95
# Processed row 18: Score = 90
# Processed row 20: Score = 90
# Processed row 21: Score = 85
# Processed row 22: Score = 90
# Processed row 25: Score = 85
# Processed row 23: Score = 90
# Processed row 27: Score = 90
# Processed row 26: Score = 90
# Processed row 24: Score = 90
# Processed row 28: Score = 90
# Processed row 29: Score = 85
# Processed row 30: Score = 95
# Processed row 31: Score = 90
# Processed row 33: Score = 85
# Processed row 32: Score = 90
# Processed row 34: Score = 95
# Processed row 36: Score = 90
# Processed row 35: Score = 90
# Processed row 38: Score = 85
# Processed row 37: Score = 90
# Processed row 39: Score = 90
# Processed row 40: Score = 85
# Processed row 41: Score = 90
# Processed row 42: Score = 90
# Processed row 43: Score = 90
# Processed row 44: Score = 95
# Processed row 45: Score = 90
# Processed row 46: Score = 90
# Processed row 48: Score = 90
# Processed row 47: Score = 90
# Processed row 49: Score = 90
# Processed row 51: Score = 90
# Processed row 50: Score = 85
# Processed row 52: Score = 90
#
# Scoring completed!
#
# Summary:
# Total rows: 52
# Successfully scored: 52
# Failed/Skipped: 0
# ✓ Scoring process completed
#
# === Generating main reports ===
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_10.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_1.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_0.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_11.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_12.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_13.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_14.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_15.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_16.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_19.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_17.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_18.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_20.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_21.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_22.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_2.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_23.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_25.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_24.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_26.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_27.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_28.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_29.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_3.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_30.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_31.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_32.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_33.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_34.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_35.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_36.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_37.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_39.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_4.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_38.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_40.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_42.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_41.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_43.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_45.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_44.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_46.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_47.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_49.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_48.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_5.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_51.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_50.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_6.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_7.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_8.html
# Report saved to CASSIA_breast_cancer_human_20250729_154121/report_cluster_9.html
# Index page saved to CASSIA_breast_cancer_human_20250729_154121/FastAnalysisResults_report.html
# ✓ Main reports generated
#
# === Analyzing low-scoring clusters ===
# Found 0 clusters with scores below 75:
# []
#
# === Cell type analysis pipeline completed ===
# All reports have been saved to the 'CASSIA_breast_cancer_human_20250729_154121' folder

# %% [markdown]
# ### Step 2: Detailed Batch Analysis

# %%
# output_name="intestine_detailed"
output_name = "breast_cancer_detailed"

# %%
# Run batch analysis
CASSIA.runCASSIA_batch(
    marker = unprocessed_markers,
    output_name = output_name,
    model = "gpt-4o-2024-08-06",
    tissue = "breast cancer",
    species = "human",
    max_workers = 6,  # Matching cluster count
    n_genes = 50,
    additional_info = None,
    provider = "openai")
# Out:
# Processing input dataframe to get top markers
#
# Analyzing cluster_0...
#
# Analyzing cluster_1...
#
# Analyzing cluster_10...
#
# Analyzing cluster_11...
#
# Analyzing cluster_12...
#
# Analyzing cluster_13...
# Analysis for cluster_12 completed.
#
#
# Analyzing cluster_14...
# Analysis for cluster_13 completed.
#
#
# Analyzing cluster_15...
# Analysis for cluster_0 completed.
#
#
# Analyzing cluster_16...
# Analysis for cluster_1 completed.
#
#
# Analyzing cluster_17...
# Analysis for cluster_10 completed.
#
#
# Analyzing cluster_18...
# Analysis for cluster_11 completed.
#
#
# Analyzing cluster_19...
# Analysis for cluster_14 completed.
#
#
# Analyzing cluster_2...
# Analysis for cluster_18 completed.
#
#
# Analyzing cluster_20...
# Analysis for cluster_17 completed.
#
#
# Analyzing cluster_21...
# cluster_16 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29355, Requested 3072. Please try again in 4.854s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_16 (attempt 2/2)...
# cluster_19 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29577, Requested 1653. Please try again in 2.46s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_19 (attempt 2/2)...
# cluster_15 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 2918. Please try again in 5.836s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_15 (attempt 2/2)...
# cluster_15 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 548. Please try again in 1.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_22...
# cluster_15 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 548. Please try again in 1.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# cluster_20 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1024. Please try again in 2.048s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_20 (attempt 2/2)...
# cluster_2 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1091. Please try again in 2.182s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_2 (attempt 2/2)...
# cluster_21 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1501. Please try again in 3.002s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_21 (attempt 2/2)...
# cluster_20 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29791, Requested 554. Please try again in 690ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_23...
# cluster_20 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29791, Requested 554. Please try again in 690ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# cluster_2 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 547. Please try again in 1.094s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_24...
# cluster_2 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 547. Please try again in 1.094s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# cluster_19 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1318. Please try again in 2.636s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_25...
# cluster_19 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1318. Please try again in 2.636s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# cluster_16 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29427, Requested 1460. Please try again in 1.774s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_26...
# cluster_16 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29427, Requested 1460. Please try again in 1.774s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# cluster_22 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29414, Requested 1356. Please try again in 1.54s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_22 (attempt 2/2)...
# cluster_24 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1365. Please try again in 2.73s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_24 (attempt 2/2)...
# cluster_25 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1301. Please try again in 2.602s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_25 (attempt 2/2)...
# cluster_24 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 551. Please try again in 1.102s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_27...
# cluster_25 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 551. Please try again in 1.102s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_28...
# cluster_27 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 546. Please try again in 1.092s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_27 (attempt 2/2)...
# cluster_28 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 29581, Requested 550. Please try again in 262ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_28 (attempt 2/2)...
# cluster_21 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1543. Please try again in 3.086s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_29...
# cluster_23 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1036. Please try again in 2.072s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_23 (attempt 2/2)...
# cluster_23 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 548. Please try again in 1.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_3...
# cluster_28 failed after 2 attempts with error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 550. Please try again in 1.1s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# Analyzing cluster_30...
# cluster_26 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 1041. Please try again in 2.082s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_26 (attempt 2/2)...
# cluster_3 generated an exception: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-I3IwHpFDeNETrS983Q5UWD6k on tokens per min (TPM): Limit 30000, Used 30000, Requested 551. Please try again in 1.102s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Retrying analysis for cluster_3 (attempt 2/2)...

# %% [markdown]
# ### Step 3: Quality Scoring

# %%
# Run quality scoring
CASSIA.runCASSIA_score_batch(
    input_file = output_name + "_full.csv",
    output_file = output_name + "_scored.csv",
    max_workers = 6,
    model = "google/gemini-2.5-flash-preview",
    provider = "openrouter"
)

# Generate quality report
CASSIA.runCASSIA_generate_score_report(
    csv_path = output_name + "_scored.csv",
    index_name = output_name + "_report.html"
)

# %% [markdown]
# ### Optional Step: Uncertainty Quantification
#
# This could be useful to study the uncertainty of the annotation, and potentially improve the accurracy.
#
# Note:This is step could be costy, since multiple iteration will be performed.

# %%
# Run multiple iterations
iteration_results = CASSIA.runCASSIA_batch_n_times(
    n=2,
    marker=unprocessed_markers,  # Changed from markers_unprocessed
    output_name=output_name + "_Uncertainty",  # Changed from paste0()
    model="openai/gpt-4o-2024-11-20",
    provider="openrouter",
    tissue="breast cancer",
    species="human",
    max_workers=6,
    batch_max_workers=3  # Conservative setting for API rate limits
)


# Calculate similarity scores
similarity_scores = CASSIA.runCASSIA_similarity_score_batch(
    marker=unprocessed_markers,  # Changed from markers_unprocessed
    file_pattern=output_name + "_Uncertainty_*_full.csv",  # Changed from paste0()
    output_name="intestine_uncertainty",
    max_workers=6,
    model="claude-3-5-sonnet-20241022",
    provider="anthropic",
    main_weight=0.5,
    sub_weight=0.5
)
# Out:
# Starting batch run 1/2
# Processing input dataframe to get top markers
# Starting batch run 2/2
# Processing input dataframe to get top markers
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing monocyte...
#
# Analyzing cd8-positive, alpha-beta t cell...
#
# Analyzing plasma cell...
#
# Analyzing intestinal crypt stem cell...
#
# Analyzing transit amplifying cell of large intestine...
#
# Analyzing intestinal enteroendocrine cell...
#
# Analyzing monocyte...
#
# Analyzing plasma cell...
#
# Analyzing transit amplifying cell of large intestine...
# Analysis for transit amplifying cell of large intestine completed.
#
# Analysis for plasma cell completed.
#
# Analysis for monocyte completed.
#
# Analysis for intestinal enteroendocrine cell completed.
#
# Analysis for intestinal crypt stem cell completed.
#
# Analysis for plasma cell completed.
#
# Analysis for transit amplifying cell of large intestine completed.
#
# Analysis for intestinal crypt stem cell completed.
#
# Analysis for monocyte completed.
#
# Analysis for intestinal enteroendocrine cell completed.
#
# Analysis for cd8-positive, alpha-beta t cell completed.
#
# All analyses completed. Results saved to 'intestine_detailed_Uncertainty_0.json'.
# Two CSV files have been created:
# 1. intestine_detailed_Uncertainty_0_full.csv (full data)
# 2. intestine_detailed_Uncertainty_0_summary.csv (summary data)
# Finished batch run 1/2 in 24.48 seconds
# Batch run 1/2 completed and saved to intestine_detailed_Uncertainty_0.json
# Analysis for cd8-positive, alpha-beta t cell completed.
#
# All analyses completed. Results saved to 'intestine_detailed_Uncertainty_1.json'.
# Two CSV files have been created:
# 1. intestine_detailed_Uncertainty_1_full.csv (full data)
# 2. intestine_detailed_Uncertainty_1_summary.csv (summary data)
# Finished batch run 2/2 in 30.04 seconds
# Batch run 2/2 completed and saved to intestine_detailed_Uncertainty_1.json
# All 2 batch runs completed in 30.04 seconds
# Organizing batch results...
# Processing cell type results...
#
# Processing cell type: cd8-positive, alpha-beta t cell
# Number of predictions: 2
# Number of valid predictions: 2
# Starting the process of cell type batch variance analysis...
#
# Processing cell type: intestinal crypt stem cell
# Number of predictions: 2
# Number of valid predictions: 2
# Starting the process of cell type batch variance analysis...
#
# Processing cell type: intestinal enteroendocrine cell
# Number of predictions: 2
# Number of valid predictions: 2
# Starting the process of cell type batch variance analysis...
#
# Processing cell type: monocyte
# Number of predictions: 2
# Number of valid predictions: 2
# Starting the process of cell type batch variance analysis...
#
# Processing cell type: plasma cell
# Number of predictions: 2
# Number of valid predictions: 2
# Starting the process of cell type batch variance analysis...
#
# Processing cell type: transit amplifying cell of large intestine
# Number of predictions: 2
# Number of valid predictions: 2
# Starting the process of cell type batch variance analysis...
# result1:(Plasma Cell, IgA-secreting Plasma Cell),result2:(Plasma Cell, IgA-secreting Plasma Cell)
# result1:(Proliferative Epithelial Cell, Transit-Amplifying (TA) Cell),result2:(Proliferative Epithelial Cell, Transit-Amplifying (TA) Cell)
# result1:(Cytotoxic T Cell, Tissue-Resident Memory Cd8+ T Cell),result2:(Cytotoxic T Cell, Cytotoxic T Cell)
# Let me analyze these results step by step:
#
# 1. Looking at the general cell type:
# - Both results show "Plasma Cell"
# - 100% agreement on the general cell type
#
# 2. Looking at the subtypes:
# - Both results show "IgA-secreting Plasma Cell"
# - 100% agreement on the subtype
#
# 3. Analysis of consistency:
# - Perfect agreement between both runs
# - No evidence of mixed cell types
# - Both general and subtype classifications are identical
# - This suggests a very robust classification
#
# 4. Confidence assessment:
# - With identical results across runs
# - Clear plasma cell markers must be present
# - Specific IgA markers must be consistently detected
# - This indicates a very high confidence classification
#
# <json>{
# "final_results": [
# "Plasma Cell",
# "IgA-secreting Plasma Cell"
# ],
# "possible_mixed_celltypes": [],
# "consensus_score": 100
# }</json>
#
# The consensus score is 100 because we have perfect agreement between runs for both the general cell type and subtype. There's no evidence of mixed cell types. This appears to be a very clear and robust classification of an IgA-secreting plasma cell.
# Plasma Cell
# General celltype: Plasma Cell
# Sub celltype: IgA-secreting Plasma Cell
# Mixed types: []
# LLM generated consensus score: 100
# Processing successful for plasma cell
# Let me analyze these results step by step:
#
# 1. Looking at Result 1:
# - General cell type: Proliferative Epithelial Cell
# - Subtype: Transit-Amplifying (TA) Cell
#
# 2. Looking at Result 2:
# - General cell type: Proliferative Epithelial Cell
# - Subtype: Transit-Amplifying (TA) Cell
#
# 3. Analysis:
# - Both results show perfect agreement
# - Both identify the same general cell type (Proliferative Epithelial Cell)
# - Both identify the same subtype (Transit-Amplifying (TA) Cell)
# - There is no evidence of mixed cell types
# - The results are highly consistent across runs
#
# 4. Confidence Assessment:
# - With 100% agreement between runs
# - Both general and subtypes matching exactly
# - This indicates a very robust classification
#
# <json>{
# "final_results": [
# "Proliferative Epithelial Cell",
# "Transit-Amplifying (TA) Cell"
# ],
# "possible_mixed_celltypes": [],
# "consensus_score": 100
# }</json>
#
# The consensus score is 100 because we have perfect agreement between the two results, both at the general cell type and subtype level. This suggests a very clear and unambiguous cell identity.
# Proliferative Epithelial Cell
# General celltype: Proliferative Epithelial Cell
# Sub celltype: Transit-Amplifying (TA) Cell
# Mixed types: []
# LLM generated consensus score: 100
# Processing successful for transit amplifying cell of large intestine
# Let me analyze these results step by step:
#
# 1. Analyzing general cell types:
# - Both results show "Cytotoxic T Cell" as the general cell type
# - This shows 100% agreement on the general cell type
#
# 2. Analyzing subtypes:
# - Result 1 shows "Tissue-Resident Memory Cd8+ T Cell"
# - Result 2 shows "Cytotoxic T Cell"
# - Both subtypes are related to cytotoxic T cell lineage, but with different specificity
#
# 3. Reasoning for final call:
# - The general cell type is clearly Cytotoxic T Cell
# - For the subtype, since one result is more specific (Tissue-Resident Memory CD8+ T Cell) and this is a known subtype of cytotoxic T cells, we can use this more detailed annotation
# - No evidence of mixed cell types as both results point to cytotoxic T cell lineage
#
# 4. Consensus score calculation:
# - General cell type agreement: 100%
# - Subtype partial agreement (both in cytotoxic lineage): ~80%
# - Overall consensus score: 90
#
# <json>{
# "final_results": [
# "Cytotoxic T Cell",
# "Tissue-Resident Memory CD8+ T Cell"
# ],
# "possible_mixed_celltypes": [],
# "consensus_score": 90
# }</json>
# Cytotoxic T Cell
# General celltype: Cytotoxic T Cell
# Sub celltype: Tissue-Resident Memory CD8+ T Cell
# Mixed types: []
# LLM generated consensus score: 90
# Processing successful for cd8-positive, alpha-beta t cell
# result1:(Intestinal Epithelial Cell, Intestinal Stem Cell (ISC)),result2:(Intestinal Epithelial Cell, Intestinal Stem Cell (ISC))
# result1:(Neural/Glial Cell, Oligodendrocyte Progenitor Cell (OPC)),result2:(Neural/Glial Cell, Oligodendrocyte Progenitor Cell (OPC))
# result1:(Enteroendocrine Cell, Enteroendocrine L-cell),result2:(Enteroendocrine Cell, L-cell)
# Let me analyze these results step by step:
#
# 1. Looking at Result 1:
# - General cell type: Intestinal Epithelial Cell
# - Subtype: Intestinal Stem Cell (ISC)
#
# 2. Looking at Result 2:
# - General cell type: Intestinal Epithelial Cell
# - Subtype: Intestinal Stem Cell (ISC)
#
# 3. Analysis:
# - Both results are exactly the same
# - Both identify the cell as an Intestinal Epithelial Cell
# - Both specifically identify it as an Intestinal Stem Cell (ISC)
# - There is perfect agreement between the results
# - No evidence of mixed cell types
# - The consistency between runs suggests high confidence in the annotation
#
# 4. Consensus evaluation:
# - With perfect agreement between runs, this deserves the highest consensus score
# - Both general type and subtype match exactly
# - Score: 100/100
#
# Here's the formal output:
#
# <json>{
# "final_results": [
# "Intestinal Epithelial Cell",
# "Intestinal Stem Cell (ISC)"
# ],
# "possible_mixed_celltypes": [],
# "consensus_score": 100
# }</json>
# Intestinal Epithelial Cell
# General celltype: Intestinal Epithelial Cell
# Sub celltype: Intestinal Stem Cell (ISC)
# Mixed types: []
# LLM generated consensus score: 100
# Processing successful for intestinal crypt stem cell
# Let me analyze these results step by step:
#
# 1. Looking at the general cell type:
# - Result 1: Enteroendocrine Cell
# - Result 2: Enteroendocrine Cell
# -> Perfect agreement on the general cell type (100% match)
#
# 2. Looking at the subtypes:
# - Result 1: Enteroendocrine L-cell
# - Result 2: L-cell
# -> These are essentially the same subtype, just written slightly differently. L-cell is simply a shorter way of writing Enteroendocrine L-cell.
#
# 3. Analyzing consistency:
# - Both results point to the exact same cell identity
# - No evidence of mixed cell types
# - The annotations are extremely consistent across runs
#
# 4. Confidence assessment:
# - The perfect agreement between runs
# - The consistent identification of L-cell subtype
# - The biological coherence (L-cells are indeed a well-known subtype of enteroendocrine cells)
# -> This suggests a very high confidence in the annotation
#
# <json>{
# "final_results": [
# "Enteroendocrine Cell",
# "L-cell"
# ],
# "possible_mixed_celltypes": [],
# "consensus_score": 100
# }</json>
#
# The consensus score is 100 because there is perfect agreement between the runs, both at the general cell type level and the subtype level (accounting for the slight difference in nomenclature).
# Enteroendocrine Cell
# General celltype: Enteroendocrine Cell
# Sub celltype: L-cell
# Mixed types: []
# LLM generated consensus score: 100
# Processing successful for intestinal enteroendocrine cell
# Let me analyze these results step by step:
#
# 1. Looking at Result 1:
# - General cell type: Neural/Glial Cell
# - Subtype: Oligodendrocyte Progenitor Cell (OPC)
#
# 2. Looking at Result 2:
# - General cell type: Neural/Glial Cell
# - Subtype: Oligodendrocyte Progenitor Cell (OPC)
#
# 3. Analysis:
# - Both results are exactly identical
# - Both identify the cells as Neural/Glial cells, specifically OPCs
# - OPCs are well-known precursor cells that give rise to oligodendrocytes
# - There is perfect agreement between the two results
# - No evidence of mixed cell types
#
# 4. Confidence Assessment:
# - With 100% agreement between results
# - Both general type and subtype matching perfectly
# - This suggests a very robust identification
#
# <json>{
# "final_results": [
# "Neural/Glial Cell",
# "Oligodendrocyte Progenitor Cell (OPC)"
# ],
# "possible_mixed_celltypes": [],
# "consensus_score": 100
# }</json>
#
# The consensus score is 100 because we have perfect agreement between the two results, both at the general cell type level and the specific subtype level. This is a very robust identification of OPCs.
# Neural/Glial Cell
# General celltype: Neural/Glial Cell
# Sub celltype: Oligodendrocyte Progenitor Cell (OPC)
# Mixed types: []
# LLM generated consensus score: 100
# Processing successful for monocyte
# Creating and saving results dataframe...
#
# Results saved to intestine_similarity2.csv
# Results have been processed and saved to intestine_similarity2

# %% [markdown]
# ### Optional Step: Annotation Boost on Selected Cluster
#
# The monocyte cluster is sometimes annotated as mixed population of immune cell and neuron/glia cells.
#
# Here we use annotation boost agent to test these hypothesis in more detail.

# %%
# Run validation plus for the high mitochondrial content cluster
CASSIA.runCASSIA_annotationboost(
    full_result_path = output_name + "_full.csv",
    marker = unprocessed_markers,
    output_name = "monocyte_annotationboost",
    cluster_name = "monocyte",
    major_cluster_info = "Human Large Intestine",
    num_iterations = 5,
    model = "anthropic/claude-3.5-sonnet",
    provider = "openrouter"
)

# %% [markdown]
# ### Optional Step: Retrieve Augmented Generation
#
# This is particularly useful if you have a very specific and detialed annottaion to work with. It can significantly imrpove the granularity and accuracy of the annotation. It automatically extract marker information and genearte a report as additional informatyion for default CASSIA pipeline.

# %% [markdown]
# Intsall the package

# %%
# !pip install cassia-rag

# %%
# !pip install cassia-rag
from cassia_rag import run_complete_analysis
import os
# Out:
# Running cells with 'cassia_rag (Python 3.11.10)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\anaconda3\envs\cassia_rag ipykernel --update-deps --force-reinstall'

# %% [markdown]
# Set up the API keys if you have not done so.

# %%
os.environ["ANTHROPIC_API_KEY"] = "your-anthropic-key"
os.environ["OPENAI_API_KEY"] = "your-openai-key"

# %% [markdown]
# Run the wrapper function to trigger a multiagent pipeline.

# %% [markdown]
# run_complete_analysis(
#         tissue_type="Liver", # tissue you are analyzing
#         target_species="Tiger", # species you are analyzing
#         reference_species="Human", # either Human or mouse, if other species, then use Human instead of mouse
#         model_choice='claude', # either claude or gpt, highly recommend claude
#         compare=True,  # if you want to compare with reference species, for example fetal vs human, then set to True
#         db_path="~/Canonical_Marker (1).csv", # path to the database
#         max_workers=8
# )

# %% [markdown]
# All the outputs (intermediate and final) are saved as a txt file in the "TissueType_Species" folder. In our example, it is Liver_Tiger folder.
# Final output is in summary_clean.txt file. And the content in this file can be used as additional information in CASSIA pipeline later.
#
# There are also some other files in the folder, which are intermediate outputs.
# Use the tutorial input as example, the files are:
# 1. liver_tiger_marker_analysis.txt # marker analysis and interpretation from the database
# 2. final_ontology.txt # ontology related to the tissue type and target species
# 3. cell_type_patterns_claude.txt # cell type patterns analysis from the
# 4. summary.txt # raw summary file
# 5. additional_considerations.txt # additional considerations if we have different species than reference species.

# %% [markdown]
# ### Optional Step: Compare the Subtypes Using Multiple LLMs
#
# This agent can be used after you finish the default CASSIA pipeline, and are still unsure about a celltype. You can use this agent to get a more confident subtype annotation. Here we use the Plasma Cells cluster as examples. To distinguish if it is more like a general plasma cell or other celltypes.

# %%
# The marker here are copy from CASSIA's previous results.
marker = "IGLL5, IGLV6-57, JCHAIN, FAM92B, IGLC3, IGLC2, IGHV3-7, IGKC, TNFRSF17, IGHG1, AC026369.3, IGHV3-23, IGKV4-1, IGKV1-5, IGHA1, IGLV3-1, IGLV2-11, MYL2, MZB1, IGHG3, IGHV3-74, IGHM, ANKRD36BP2, AMPD1, IGKV3-20, IGHA2, DERL3, AC104699.1, LINC02362, AL391056.1, LILRB4, CCL3, BMP6, UBE2QL1, LINC00309, AL133467.1, GPRC5D, FCRL5, DNAAF1, AP002852.1, AC007569.1, CXorf21, RNU1-85P, U62317.4, TXNDC5, LINC02384, CCR10, BFSP2, APOBEC3A, AC106897.1"

CASSIA.compareCelltypes(
    tissue = "large intestine",
    celltypes = ["Plasma Cells", "IgA-secreting Plasma Cells", "IgG-secreting Plasma Cells", "IgM-secreting Plasma Cells"],
    marker_set = marker,
    species = "human",
    output_file = "plasama_cell_subtype"
)

# %% [markdown]
# ### Optional Step: Subclustering
#
#
# This agent can be used to study subclustered population, such as a T cell population or a Fibroblast cluster. We recommend to apply the default cassia first, and on a target cluster, apply Seurat pipeline to subcluster the cluster and get the findallmarke results to be used here. Here we present the results for the cd8-positive, alpha-beta t cell cluster as example. This cluster is a cd8 population mixed with other celltypes.

# %%
##below are R code or can be done in Scanpy too

# large=readRDS("/Users/xie227/Downloads/seurat_object.rds")
# # Extract CD8+ T cells
# cd8_cells <- subset(large, cell_ontology_class == "cd8-positive, alpha-beta t cell")
# # Normalize and identify variable features
# cd8_cells <- NormalizeData(cd8_cells)
# cd8_cells <- FindVariableFeatures(cd8_cells, selection.method = "vst", nfeatures = 2000)
# # Scale data and run PCA
# all.genes <- rownames(cd8_cells)
# cd8_cells <- ScaleData(cd8_cells, features = all.genes)
# cd8_cells <- RunPCA(cd8_cells, features = VariableFeatures(object = cd8_cells),npcs = 30)
# # Run clustering (adjust resolution and dims as needed based on elbow plot)
# cd8_cells <- FindNeighbors(cd8_cells, dims = 1:20)
# cd8_cells <- FindClusters(cd8_cells, resolution = 0.3)
# # Run UMAP
# cd8_cells <- RunUMAP(cd8_cells, dims = 1:20)
# # Create visualization plots
# p1 <- DimPlot(cd8_cells, reduction = "umap", label = TRUE) +
#   ggtitle("CD8+ T Cell Subclusters")
# # Find markers for each subcluster
# cd8_markers <- FindAllMarkers(cd8_cells,
#                             only.pos = TRUE,
#                             min.pct = 0.1,
#                             logfc.threshold = 0.25)
# cd8_markers=cd8_markers %>% filter(p_val_adj<0.05)
# write.csv(cd8_markers, "cd8_subcluster_markers.csv")

CASSIA.runCASSIA_subclusters(marker = subcluster_results,
    major_cluster_info = "cd8 t cell",
    output_name = "subclustering_results",
    model = "anthropic/claude-3.5-sonnet",
    provider = "openrouter")

# %% [markdown]
# It is recommend to run the CS score for the subclustering to get a more confident answer.

# %%
CASSIA.runCASSIA_n_subcluster(
    n=5, 
    marker=subcluster_results,
    major_cluster_info="cd8 t cell", 
    base_output_name="subclustering_results_n",
    model="anthropic/claude-3.5-sonnet",
    temperature=0,
    provider="openrouter",
    max_workers=5,
    n_genes=50
)

# %%
# Calculate similarity scores
CASSIA.runCASSIA_similarity_score_batch(
    marker = subcluster_results,
    file_pattern = "subclustering_results_n_*.csv",
    output_name = "subclustering_uncertainty",
    max_workers = 6,
    model = "claude-3-5-sonnet-20241022",
    provider = "anthropic",
    main_weight = 0.5,
    sub_weight = 0.5
)

# %% [markdown]
# ### Optional Step: Annotation Boost with Additional Task
#
# This can be used to study a given problem related to a cluster, such as infer the state of a cluster. Here we use the cd8-positive, alpha-beta t cell as an example. Note that the performance of this agent has not been benchmarked, so please be cautious with the results.

# %%
#only openrouter is supported as provider now.

CASSIA.runCASSIA_annottaionboost_additional_task(
    full_result_path = output_name + "_full.csv",  # Changed from paste0() to Python string concatenation
    marker = unprocessed_markers,
    output_name = "T_cell_state",
    cluster_name = "cd8-positive, alpha-beta t cell",  # Cluster with high mitochondrial content
    major_cluster_info = "Human Large Intestine",
    num_iterations = 5,
    model = "anthropic/claude-3.5-sonnet",
    additional_task = "infer the state of this T cell cluster"
)
